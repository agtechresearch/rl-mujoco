# %%
# https://colab.research.google.com/github/Stable-Baselines-Team/rl-colab-notebooks/blob/sb3/saving_loading_dqn.ipynb#scrollTo=gWskDE2c9WoN``
# !pip install -q box2d-py

# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN

model = DQN(
    "MlpPolicy",
    "LunarLander-v2",
    verbose=1,
    exploration_final_eps=0.1,
    target_update_interval=250,
)
# Out:
# Using cuda device
# Creating environment from the given name 'LunarLander-v2'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Separate env for evaluation
eval_env = gym.make("LunarLander-v2")

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    deterministic=True,
)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=-474.98 +/- 144.1345513732366
# /home/egtechlab/anaconda3/envs/mujoco_env/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
# Train the agent
model.learn(total_timesteps=int(1e5))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -99.6    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5649     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7968     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 707      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 9035     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 9748     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 10188    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -142     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 10559    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 10847    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11010    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11195    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11276    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 11392    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 11474    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11552    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11614    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11634    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11705    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11763    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11815    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11876    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8027     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8174     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8692     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8276     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8393     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.119    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8504     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8609     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8710     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8800     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 8904     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8994     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11706    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 9068     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 9153     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 9229     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 9303     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 9372     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 9442     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 9505     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 9575     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 9632     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 9686     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 9737     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 9786     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 9835     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 9891     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 9948     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17284    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 10002    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 10054    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 10098    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 10141    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 10178    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10216    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10259    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10294    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10328    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 10367    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 10400    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 10430    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 10458    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 10488    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 10522    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 10551    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 23274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 10580    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 23663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 10605    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 10631    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 10658    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 10684    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 10709    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 25425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 10733    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 25708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 10755    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 10778    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 10802    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 10824    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 10846    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 10869    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 10888    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 10912    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 10932    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 10949    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 10971    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 10989    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 30105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 11005    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 30412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 11024    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 30808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 11044    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 31176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 11058    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 31568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 11074    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 31898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 11088    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 32328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 11106    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 32725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 11120    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 33120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 11136    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 33487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 11153    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 33919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 11171    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 34284    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 11188    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 34701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 11199    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 11213    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 11229    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 11241    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 11253    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 11270    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 11283    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 37311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 11295    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 37799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 11307    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 11317    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 11330    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 11342    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 39315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 11351    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 39689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 11359    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 40147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 11371    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 40534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 11382    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 40985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 11393    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 41321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 11405    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 41645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 11416    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 41922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 11428    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 42256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 11439    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 42602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 11451    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 42972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 11459    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 43405    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 11469    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 43751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 11478    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 44130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 11483    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 44538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 11493    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 44941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 11503    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 45255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 11513    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 45597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 11522    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 45939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 11530    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 46347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 11539    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 46705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 11547    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 47076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 11556    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 47446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 11562    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 47905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 11569    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 48254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 11578    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 48553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 11587    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 48829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 11595    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 49230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 11601    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 49551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 11609    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 49903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 11184    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 50154    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 10962    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 50446    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 111      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -228     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 10746    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 50752    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94     |
# |    n_updates        | 187      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -252     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 10385    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 51240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -268     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 10110    |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 51659    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.24     |
# |    n_updates        | 414      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -338     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 9404     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 52594    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.904    |
# |    n_updates        | 648      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -351     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 9172     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 53004    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 750      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -377     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 8862     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 53601    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 900      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -391     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 8548     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 54275    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 1068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -384     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 6033     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 57556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -380     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 4654     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 61556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 2888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | -379     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 3891     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 65556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54     |
# |    n_updates        | 3888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | -376     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 3416     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 69556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 4888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | -368     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 3168     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 73130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 5782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 306      |
# |    ep_rew_mean      | -359     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 2947     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 76930    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 6732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 326      |
# |    ep_rew_mean      | -343     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 2871     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 79269    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.66     |
# |    n_updates        | 7317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 350      |
# |    ep_rew_mean      | -338     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 2722     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 82121    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.04     |
# |    n_updates        | 8030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 371      |
# |    ep_rew_mean      | -333     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2639     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 84509    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.876    |
# |    n_updates        | 8627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 386      |
# |    ep_rew_mean      | -325     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 2590     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 86532    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.865    |
# |    n_updates        | 9132     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | -312     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 2542     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 88615    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29     |
# |    n_updates        | 9653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | -297     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 2465     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 91421    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.86     |
# |    n_updates        | 10355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 2435     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 93553    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.64     |
# |    n_updates        | 10888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | -272     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 2406     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 95426    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 11356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 475      |
# |    ep_rew_mean      | -262     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 2390     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 97021    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 11755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 489      |
# |    ep_rew_mean      | -257     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 2367     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 98800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.925    |
# |    n_updates        | 12199    |
# ----------------------------------

# %%
model = DQN.load("dqn_lunar")

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=187.69 +/- 72.3907139697342

# %%
import time
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

import gymnasium as gym

from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
def make_env(env_id, rank, seed=0):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """

    def _init():
        env = gym.make(env_id)
        # use a seed for reproducibility
        # Important: use a different seed for each environment
        # otherwise they would generate the same experiences
        env.reset(seed=seed + rank)
        return env

    set_random_seed(seed)
    return _init

# %%
env_id = "CartPole-v1"
# The different number of processes that will be used
PROCESSES_TO_TEST = [1, 2, 4, 8, 16]
NUM_EXPERIMENTS = 3  # RL algorithms can often be unstable, so we run several experiments (see https://arxiv.org/abs/1709.06560)
TRAIN_STEPS = 5000
# Number of episodes for evaluation
EVAL_EPS = 20
ALGO = A2C

# We will create one environment to evaluate the agent on
eval_env = gym.make(env_id)

# %%
reward_averages = []
reward_std = []
training_times = []
total_procs = 0
for n_procs in PROCESSES_TO_TEST:
    total_procs += n_procs
    print(f"Running for n_procs = {n_procs}")
    if n_procs == 1:
        # if there is only one process, there is no need to use multiprocessing
        train_env = DummyVecEnv([lambda: gym.make(env_id)])
    else:
        # Here we use the "fork" method for launching the processes, more information is available in the doc
        # This is equivalent to make_vec_env(env_id, n_envs=n_procs, vec_env_cls=SubprocVecEnv, vec_env_kwargs=dict(start_method='fork'))
        train_env = SubprocVecEnv(
            [make_env(env_id, i + total_procs) for i in range(n_procs)],
            start_method="fork",
        )

    rewards = []
    times = []

    for experiment in range(NUM_EXPERIMENTS):
        # it is recommended to run several experiments due to variability in results
        train_env.reset()
        model = ALGO("MlpPolicy", train_env, verbose=0)
        start = time.time()
        model.learn(total_timesteps=TRAIN_STEPS)
        times.append(time.time() - start)
        mean_reward, _ = evaluate_policy(model, eval_env, n_eval_episodes=EVAL_EPS)
        rewards.append(mean_reward)
    # Important: when using subprocesses, don't forget to close them
    # otherwise, you may have memory issues when running a lot of experiments
    train_env.close()
    reward_averages.append(np.mean(rewards))
    reward_std.append(np.std(rewards))
    training_times.append(np.mean(times))
# Out:
# Running for n_procs = 1
# /home/egtechlab/anaconda3/envs/mujoco_env/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Running for n_procs = 2
# Running for n_procs = 4
# Running for n_procs = 8
# Running for n_procs = 16

# %%
def plot_training_results(training_steps_per_second, reward_averages, reward_std):
    """
    Utility function for plotting the results of training

    :param training_steps_per_second: List[double]
    :param reward_averages: List[double]
    :param reward_std: List[double]
    """
    plt.figure(figsize=(9, 4))
    plt.subplots_adjust(wspace=0.5)
    plt.subplot(1, 2, 1)
    plt.errorbar(
        PROCESSES_TO_TEST,
        reward_averages,
        yerr=reward_std,
        capsize=2,
        c="k",
        marker="o",
    )
    plt.xlabel("Processes")
    plt.ylabel("Average return")
    plt.subplot(1, 2, 2)
    plt.bar(range(len(PROCESSES_TO_TEST)), training_steps_per_second)
    plt.xticks(range(len(PROCESSES_TO_TEST)), PROCESSES_TO_TEST)
    plt.xlabel("Processes")
    plt.ylabel("Training steps per second")

training_steps_per_second = [TRAIN_STEPS / t for t in training_times]

plot_training_results(training_steps_per_second, reward_averages, reward_std)

# %%
SECONDS_PER_EXPERIMENT = 10
steps_per_experiment = [int(SECONDS_PER_EXPERIMENT * fps) for fps in training_steps_per_second]
reward_averages = []
reward_std = []
training_times = []

for n_procs, train_steps in zip(PROCESSES_TO_TEST, steps_per_experiment):
    total_procs += n_procs
    print(f"Running for n_procs = {n_procs} for steps = {train_steps}")
    if n_procs == 1:
        # if there is only one process, there is no need to use multiprocessing
        train_env = DummyVecEnv([lambda: gym.make(env_id)])
    else:
        train_env = SubprocVecEnv([make_env(env_id, i+total_procs) for i in range(n_procs)], start_method="spawn")
        # Alternatively, you can use a DummyVecEnv if the communication delays is the bottleneck
        # train_env = DummyVecEnv([make_env(env_id, i+total_procs) for i in range(n_procs)])

    rewards = []
    times = []

    for experiment in range(NUM_EXPERIMENTS):
        # it is recommended to run several experiments due to variability in results
        train_env.reset()
        model = ALGO("MlpPolicy", train_env, verbose=0)
        start = time.time()
        model.learn(total_timesteps=train_steps)
        times.append(time.time() - start)
        mean_reward, _ = evaluate_policy(model, eval_env, n_eval_episodes=EVAL_EPS)
        rewards.append(mean_reward)

    train_env.close()
    reward_averages.append(np.mean(rewards))
    reward_std.append(np.std(rewards))
    training_times.append(np.mean(times))
# Out:
# Running for n_procs = 1 for steps = 15313
# /home/egtechlab/anaconda3/envs/mujoco_env/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Running for n_procs = 2 for steps = 26753
# Running for n_procs = 4 for steps = 51140
# Running for n_procs = 8 for steps = 95246
# Running for n_procs = 16 for steps = 166166

# %%
training_steps_per_second = [s / t for s,t in zip(steps_per_experiment, training_times)]

plot_training_results(training_steps_per_second, reward_averages, reward_std)

# %%
reward_averages = []
reward_std = []
training_times = []
total_procs = 0
for n_procs in PROCESSES_TO_TEST:
    total_procs += n_procs
    print(f'Running for n_procs = {n_procs}')
    # Here we are using only one process even for n_env > 1
    # this is equivalent to DummyVecEnv([make_env(env_id, i + total_procs) for i in range(n_procs)])
    train_env = make_vec_env(env_id, n_envs=n_procs)

    rewards = []
    times = []

    for experiment in range(NUM_EXPERIMENTS):
        # it is recommended to run several experiments due to variability in results
        train_env.reset()
        model = ALGO("MlpPolicy", train_env, verbose=0)
        start = time.time()
        model.learn(total_timesteps=TRAIN_STEPS)
        times.append(time.time() - start)
        mean_reward, _ = evaluate_policy(model, eval_env, n_eval_episodes=EVAL_EPS)
        rewards.append(mean_reward)

    train_env.close()
    reward_averages.append(np.mean(rewards))
    reward_std.append(np.std(rewards))
    training_times.append(np.mean(times))

training_steps_per_second = [TRAIN_STEPS / t for t in training_times]

plot_training_results(training_steps_per_second, reward_averages, reward_std)
